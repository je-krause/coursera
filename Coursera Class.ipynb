# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Jenna**
# Data Science Engineer

# %% [markdown]
# _I am interested in data science because I enjoy solving problems. Data science also provides fairly complex problems which keep me on my toes._

# %% [markdown]
# ### The next cell will be executing one plus one.

# %%
1 + 1
# Out:
# 2

# %% [markdown]
# ![Image of Ronald Coase](data:image/jpeg;base64,...)
# [Data Science Quotes](https://towardsdatascience.com/top-15-famous-data-science-quotes-f2e010b8d214)
# >“Torture the data, and it will confess to anything.”
# (Ronald Coase, Economics, Nobel prize Laureate)
